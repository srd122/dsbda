# %%
import numpy as np 
import pandas as pd

# %%
df=pd.read_csv('Air-Quality.csv')
df
# Out:
#      Ozone  Solar.R  Wind   Temp  Month  Day  Unnamed: 6  Unnamed: 7  \
# 0        2        1  41.0  190.0    7.4   67           5           1
# 1        3        2  36.0  118.0    8.0   72           5           2
# 2        4        3  12.0  149.0   12.6   74           5           3
# 3        5        4  18.0  313.0   11.5   62           5           4
# 4        6        5   NaN    NaN   14.3   56           5           5
# ..     ...      ...   ...    ...    ...  ...         ...         ...
# 148    150      149  30.0  193.0    6.9   70           9          26
# 149    151      150   NaN  145.0   13.2   77           9          27
# 150    152      151  14.0  191.0   14.3   75           9          28
# 151    153      152  18.0  131.0    8.0   76           9          29
# 152    154      153  20.0  223.0   11.5   68           9          30
#
#        patient_id
# 0    1.000000e+00
# 1    2.000000e+00
# 2    3.000000e+00
# 3    5.000000e+00
# 4    8.000000e+00
# ..            ...
# ...

# %%
df.head()
# Out:
#    Ozone  Solar.R  Wind   Temp  Month  Day  Unnamed: 6  Unnamed: 7  patient_id
# 0      2        1  41.0  190.0    7.4   67           5           1         1.0
# 1      3        2  36.0  118.0    8.0   72           5           2         2.0
# 2      4        3  12.0  149.0   12.6   74           5           3         3.0
# 3      5        4  18.0  313.0   11.5   62           5           4         5.0
# 4      6        5   NaN    NaN   14.3   56           5           5         8.0

# %%
df2=df.iloc[0:15]
df2
# Out:
#     Ozone  Solar.R  Wind   Temp  Month  Day  Unnamed: 6  Unnamed: 7  \
# 0       2        1  41.0  190.0    7.4   67           5           1
# 1       3        2  36.0  118.0    8.0   72           5           2
# 2       4        3  12.0  149.0   12.6   74           5           3
# 3       5        4  18.0  313.0   11.5   62           5           4
# 4       6        5   NaN    NaN   14.3   56           5           5
# 5       7        6  28.0    NaN   14.9   66           5           6
# 6       8        7  23.0  299.0    8.6   65           5           7
# 7       9        8  19.0   99.0   13.8   59           5           8
# 8      10        9   8.0   19.0   20.1   61           5           9
# 9      11       10   NaN  194.0    8.6   69           5          10
# 10     12       11   7.0    NaN    6.9   74           5          11
# 11     13       12  16.0  256.0    9.7   69           5          12
# 12     14       13  11.0  290.0    9.2   66           5          13
# ...

# %%
df3=df.drop_duplicates(inplace=True)
df3

# %%
df
# Out:
#      Ozone  Solar.R  Wind   Temp  Month  Day  Unnamed: 6  Unnamed: 7  \
# 0        2        1  41.0  190.0    7.4   67           5           1
# 1        3        2  36.0  118.0    8.0   72           5           2
# 2        4        3  12.0  149.0   12.6   74           5           3
# 3        5        4  18.0  313.0   11.5   62           5           4
# 4        6        5   NaN    NaN   14.3   56           5           5
# ..     ...      ...   ...    ...    ...  ...         ...         ...
# 148    150      149  30.0  193.0    6.9   70           9          26
# 149    151      150   NaN  145.0   13.2   77           9          27
# 150    152      151  14.0  191.0   14.3   75           9          28
# 151    153      152  18.0  131.0    8.0   76           9          29
# 152    154      153  20.0  223.0   11.5   68           9          30
#
#        patient_id
# 0    1.000000e+00
# 1    2.000000e+00
# 2    3.000000e+00
# 3    5.000000e+00
# 4    8.000000e+00
# ..            ...
# ...

# %%
dataset1=df[['Ozone','Solar.R','Wind','Temp','Month','Day']].loc[0:50]
dataset1
# Out:
#     Ozone  Solar.R   Wind   Temp  Month  Day
# 0       2        1   41.0  190.0    7.4   67
# 1       3        2   36.0  118.0    8.0   72
# 2       4        3   12.0  149.0   12.6   74
# 3       5        4   18.0  313.0   11.5   62
# 4       6        5    NaN    NaN   14.3   56
# 5       7        6   28.0    NaN   14.9   66
# 6       8        7   23.0  299.0    8.6   65
# 7       9        8   19.0   99.0   13.8   59
# 8      10        9    8.0   19.0   20.1   61
# 9      11       10    NaN  194.0    8.6   69
# 10     12       11    7.0    NaN    6.9   74
# 11     13       12   16.0  256.0    9.7   69
# 12     14       13   11.0  290.0    9.2   66
# 13     15       14   14.0  274.0   10.9   68
# 14     16       15   18.0   65.0   13.2   58
# 15     17       16   14.0  334.0   11.5   64
# 16     18       17   34.0  307.0   12.0   66
# 17     19       18    6.0   78.0   18.4   57
# 18     20       19   30.0  322.0   11.5   68
# 19     21       20   11.0   44.0    9.7   62
# ...

# %%
dataset1.head()
# Out:
#    Ozone  Solar.R  Wind   Temp  Month  Day
# 0      2        1  41.0  190.0    7.4   67
# 1      3        2  36.0  118.0    8.0   72
# 2      4        3  12.0  149.0   12.6   74
# 3      5        4  18.0  313.0   11.5   62
# 4      6        5   NaN    NaN   14.3   56
